# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmoodhamza1261/New-folder--2-/blob/master/Tic_tac_toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
board = [' ' for x in range(10)]

def print_board(board):
    print('   |   |')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |')

def is_winner(board, player):
    return ((board[1] == player and board[2] == player and board[3] == player) or
    (board[4] == player and board[5] == player and board[6] == player) or
    (board[7] == player and board[8] == player and board[9] == player) or
    (board[1] == player and board[4] == player and board[7] == player) or
    (board[2] == player and board[5] == player and board[8] == player) or
    (board[3] == player and board[6] == player and board[9] == player) or
    (board[1] == player and board[5] == player and board[9] == player) or
    (board[3] == player and board[5] == player and board[7] == player))

def is_board_full(board):
    return ' ' not in board[1:]

def play_game():
    player1 = 'X'
    player2 = 'O'
    current_player = player1

    while not is_board_full(board):
        print_board(board)
        move = int(input(f"Enter a position to place an '{current_player}' (1-9): "))
        if board[move] == ' ':
            board[move] = current_player
            if is_winner(board, current_player):
                print_board(board)
                print(f'Congratulations, {current_player} won the game!')
                return
            else:
                current_player = player2 if current_player == player1 else player1

    print_board(board)
    print('The game was a tie!')

play_game()
8
# Out:
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# Enter a position to place an 'X' (1-9): 1
#    |   |
#  X |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# Enter a position to place an 'O' (1-9): 2
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# Enter a position to place an 'X' (1-9): 3
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# Enter a position to place an 'O' (1-9): 4
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  O |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# Enter a position to place an 'X' (1-9): 4
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  O |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# ...
